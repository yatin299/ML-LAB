# %% [markdown]
# <a href="https://colab.research.google.com/github/yatin299/ML-LAB/blob/PCA/PCA_problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = {
    'Variable': ['Climate','Housing','Health','Crime','Transportation','Education','Arts','Recreation','Economy'],
    'PC1': [0.312, 0.478, 0.721, 0.401, 0.539, 0.298, 0.864, 0.615, 0.187],
    'PC2': [-0.042, 0.115, -0.502, 0.332, 0.198, -0.341, 0.091, 0.378, -0.210],
    'PC3': [0.156, -0.231, 0.214, 0.497, 0.301, 0.119, -0.098, 0.587, 0.269]
}

df = pd.DataFrame(data)
df.set_index('Variable', inplace=True)

print("Dataset:\n", df, "\n")

for pc in ['PC1','PC2','PC3']:
    max_var = df[pc].abs().idxmax()
    max_val = df.loc[max_var, pc]
    print(f"Highest contributor to {pc}: {max_var} (loading = {max_val})")

abs_df = df.abs()
overall_max_var = abs_df.max(axis=1).idxmax()
overall_max_val = abs_df.max(axis=1).max()
print(f"\nOverall strongest contributor: {overall_max_var} (loading = {overall_max_val})")
# Out:
# Dataset:
#                    PC1    PC2    PC3
# Variable
# Climate         0.312 -0.042  0.156
# Housing         0.478  0.115 -0.231
# Health          0.721 -0.502  0.214
# Crime           0.401  0.332  0.497
# Transportation  0.539  0.198  0.301
# Education       0.298 -0.341  0.119
# Arts            0.864  0.091 -0.098
# Recreation      0.615  0.378  0.587
# Economy         0.187 -0.210  0.269
#
# Highest contributor to PC1: Arts (loading = 0.864)
# Highest contributor to PC2: Health (loading = -0.502)
# Highest contributor to PC3: Recreation (loading = 0.587)
#
# Overall strongest contributor: Arts (loading = 0.864)
